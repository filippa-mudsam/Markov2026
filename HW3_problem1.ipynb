# %% [markdown]
# ## Homework 1 <br>
# Filippa Mudsam <br>

# %% [markdown]
# **Part c**

# %%
import numpy as np

# %%
transition_matrix = np.array([[9/10,1/10,0],[0,3/4,1/4],[1/2,0,1/2]])
print(transition_matrix)
np.linalg.matrix_power(transition_matrix, 50)
# Out:
# [[0.9  0.1  0.  ]
#  [0.   0.75 0.25]
#  [0.5  0.   0.5 ]]
# array([[0.625, 0.25 , 0.125],
#        [0.625, 0.25 , 0.125],
#        [0.625, 0.25 , 0.125]])
